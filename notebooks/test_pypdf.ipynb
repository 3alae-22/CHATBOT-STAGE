# %%
from pypdf import PdfReader
from pathlib import Path
import os

pdf_path = Path("../data/raw/Decret_marches_publics_n_2_22_431_du_09_03_2023_Fr marchés publics.pdf")
reader = PdfReader(pdf_path)

# %%
page=reader.pages[1]
text=page.extract_text()
print(text)
# Out:
# 1
# SOMMAIRE
# ****
#  Décret n° 2-22-431 du 15 chaabane 1444 (8 mars 2023) relatif aux marchés publics
#
#
# Chapitre premier : Dispositions générales 5
# ARTICLE PREMIER. – Principes généraux 5
# ART. 2. – Objet et champ d’application 5
# ART. 3. – Exclusions 5
# ART. 4. – Définitions 6
# ART. 5. – Détermination des besoins 7
# ART. 6. – Etablissement de l’estimation du coût des prestations 8
# Chapitre II : Types et prix des marchés 8
# Section première. – Types de marchés 8
# ART. 7. – Marchés-cadre 8
# ART. 8. – Marchés reconductibles 9
# ART. 9. – Marchés à tranches conditionnelles 9
# ART. 10. – Marchés allotis 10
# ART. 11. – Marché de conception-réalisation 10
# ART. 12. – Dialogue compétitif 11
# ART. 13. – Offre spontanée 12
# Section II. – Prix des marchés 12
# ART. 14. – Nature et modalités de définition des prix 12
# ART. 15. – Caractère des prix 13
# Chapitre III : Formes des marchés et modes de leur passation 13
# ART. 16. – Forme et contenu des marchés 13
# ...
